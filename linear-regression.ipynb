# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
num_rows = 1000
np.random.seed(0)
X = np.arange(num_rows)
y = 3 * X + 5 + np.random.normal(0, 750, size = num_rows)
w = None

fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(X, y, s=5, color='blue')

# Reshape for training
train = np.reshape(X, (X.size, 1))

# %%
# Training
model = linear_model.LinearRegression()
model.fit(train, y, w)

# The coefficient(s) (slope)
coef = model.coef_ 
print(coef) 

# The intercept (y-intercept)
intercept = model.intercept_
print(intercept)

# Plot
x_line = np.array([X.min(), X.max()])
y_line = coef * x_line + intercept
ax.plot(x_line, y_line, color='red')
fig
# Out:
# [2.98601979]
# -21.95941342642527

# %%
new_value = np.array([[556]])
model.predict(new_value)
# Out:
# array([1638.26758726])
